# %%
import polars as pl

sampled_df = pl.read_parquet("../data_all/above_value_minus1/sample_200k.parquet")

# %%
sampled_df.filter(pl.col("uid") == "db3093fc5c102067d68a32704764a24d")["url"]
# Out:
# shape: (1,)
# Series: 'url' [str]
# [
# 	"https://primailcanavese.it/med…
# ]
