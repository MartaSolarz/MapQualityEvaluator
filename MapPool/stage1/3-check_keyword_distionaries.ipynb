# %% [markdown]
# # Test słowników

# %%
import pandas as pd
import json

with open("./keywords/positive_keywords.json", "r", encoding="utf-8") as f:
    positive_json = json.load(f)

with open("./keywords/negative_keywords.json", "r", encoding="utf-8") as f:
    negative_json = json.load(f)


print(f"Loaded {len(positive_json)} positive keywords.")
print(f"Loaded {len(negative_json)} negative keywords.")
# Out:
# Loaded 2699 positive keywords.
# Loaded 2420 negative keywords.

# %%
import ahocorasick

A = ahocorasick.Automaton()

for phrase, value in positive_json.items():
    A.add_word(phrase.lower(), ("pos", phrase, value))

for phrase, value in negative_json.items():
    A.add_word(phrase.lower(), ("neg", phrase, value))

A.make_automaton()

# %%
df_maps = pd.read_csv("../data_samples/sample_10k_maps_with_url_status.csv")

# %%
def compute_score_full_words(text):
    if not isinstance(text, str):
        text = str(text)

    text_lower = text.lower()
    score = 0
    used_phrases = set()
    pos_keys = []
    neg_keys = []

    for end_index, (ptype, phrase, value) in A.iter(text_lower):
        start_index = end_index - len(phrase) + 1

        if (start_index == 0 or not text_lower[start_index-1].isalnum()) and \
           (end_index == len(text_lower)-1 or not text_lower[end_index+1].isalnum()):

            if phrase not in used_phrases:
                score += value
                used_phrases.add(phrase)
                if ptype == "pos":
                    pos_keys.append(phrase)
                else:
                    neg_keys.append(phrase)

    return score, pos_keys, neg_keys

# %%
df_maps[["score", "pos", "neg"]] = df_maps["text"].apply(
    lambda x: pd.Series(compute_score_full_words(x))
)

df_maps[["text", "url", "url_status", "score", "pos", "neg"]]
# Out:
#                                                     text  \
# 0                                       Australia Nuvola
# 1      French Southern Territories Rubber Stamps vect...
# 2                                  New York - Látnivalók
# 3                                     Karte mit 5 bettel
# 4      2004 Weekday Arterial Hourly Volumes: 6 p.m. t...
# ...                                                  ...
# 9997   Free Floorplan Designer floor plans and site p...
# 9998               Wolrd Map Coron Backpacker Guesthouse
# 9999                    c7d77b50192 Autopesula hinnakiri
# 10000  kaart · Kentucky · Rood · patroon · amerika · ...
# 10001                                   267 Breckenridge
#
#                                                      url url_status  score  \
# 0      http://a0.fast-meteo.com/maps/static/t_Austral...        ERR    0.0
# 1      https://cdn1.vectorstock.com/i/thumbs/22/75/fr...         OK   -5.0
# 2        http://7.hikb.at:80/img/iconmenu/attraction.png         OK    0.0
# 3      https://aa1cc5ce659c48a883597af217799a86.objec...        ERR    0.0
# 4      http://images.slideplayer.com/9/2524694/slides...         OK    0.0
# ...                                                  ...        ...    ...
# 9997   http://tse1.mm.bing.net/th?id=OIP.TUr6q0MyrZZZ...         OK  -11.0
# 9998   https://static1.squarespace.com/static/52c24d1...         OK    0.0
# 9999   https://www.tehnokuller.ee/images/tehnokuller-...         OK    0.0
# 10000  https://img.stockfresh.com/files/k/kyryloff/x/...        ERR   -8.0
# 10001  https://maps.googleapis.com/maps/api/staticmap...        ERR    0.0
#
#       pos                              neg
# 0      []                               []
# 1      []                  [stamps, image]
# 2      []                               []
# 3      []                               []
# 4      []                               []
# ...    ..                              ...
# 9997   []  [floorplan, floor plans, plans]
# 9998   []                               []
# 9999   []                               []
# 10000  []             [patroon, stockfoto]
# 10001  []                               []
#
# [10002 rows x 6 columns]

# %%
only_valid_urls_df = df_maps[df_maps['url_status'] == 'OK'].reset_index(drop=True)

df_maps_positive = only_valid_urls_df[only_valid_urls_df['score'] > 0].reset_index(drop=True)
df_maps_negative = only_valid_urls_df[only_valid_urls_df['score'] < 0].reset_index(drop=True)
df_maps_neutral = only_valid_urls_df[only_valid_urls_df['score'] == 0].reset_index(drop=True)

print(f"Total valid URLs: {len(only_valid_urls_df)}")
print(f"Positive score maps: {len(df_maps_positive)}")
print(f"Negative score maps: {len(df_maps_negative)}")
print(f"Neutral score maps: {len(df_maps_neutral)}")
# Out:
# Total valid URLs: 5475
# Positive score maps: 368
# Negative score maps: 1901
# Neutral score maps: 3206

# %%
import ipywidgets as widgets
from IPython.display import display, HTML
import numpy as np

class MapViewerBatch:
    def __init__(self, df, sort_by_score=None, batch_size=4, show_text=True):
        self.df = df.copy().reset_index(drop=True)
        self.batch_size = batch_size
        self.show_text = show_text

        if sort_by_score == 'asc':
            self.df.sort_values('score', ascending=True, inplace=True)
        elif sort_by_score == 'desc':
            self.df.sort_values('score', ascending=False, inplace=True)

        self.indices = np.arange(len(self.df))
        self.current_position = 0

        self.image_widget = widgets.Output()
        self.prev_button_top = widgets.Button(description='← Previous')
        self.next_button_top = widgets.Button(description='Next →')
        self.prev_button_bottom = widgets.Button(description='← Previous')
        self.next_button_bottom = widgets.Button(description='Next →')
        self.counter_widget = widgets.HTML()

        for btn in [self.prev_button_top, self.prev_button_bottom]:
            btn.on_click(self.show_previous)
        for btn in [self.next_button_top, self.next_button_bottom]:
            btn.on_click(self.show_next)

        self.nav_top = widgets.HBox([self.prev_button_top, self.counter_widget, self.next_button_top])
        self.nav_bottom = widgets.HBox([self.prev_button_bottom, self.next_button_bottom])

        self.container = widgets.VBox([self.nav_top, self.image_widget, self.nav_bottom])

    def get_current_indices(self):
        start = self.current_position
        end = min(self.current_position + self.batch_size, len(self.df))
        return self.indices[start:end]

    def show_images(self, b=None):
        self.image_widget.clear_output(wait=True)

        with self.image_widget:
            for idx in self.get_current_indices():
                row = self.df.iloc[idx]

                if not self.show_text:
                    info_html = f"""
                <div style='display:flex; align-items:flex-start; padding:5px; margin-bottom:15px; border:1px solid #eee; border-radius:5px;'>
                    <div style='flex:1; padding-right:10px;'>
                        <b>Score:</b> {row['score']}<br>
                        <b>Positive keywords:</b> {', '.join(row['pos']) if row['pos'] else 'None'}<br>
                        <b>Negative keywords:</b> {', '.join(row['neg']) if row['neg'] else 'None'}<br>
                        <b>Text-image similarity:</b> {row['clip_l14_similarity_score']}</br>
                    </div>
                    <div>
                        <img src="{row["url"]}" style="max-width:300px; border:2px solid #ddd; border-radius:5px;">
                    </div>
                </div>
                """
                else:
                    info_html = f"""
                    <div style='display:flex; align-items:flex-start; padding:5px; margin-bottom:15px; border:1px solid #eee; border-radius:5px;'>
                        <div style='flex:1; padding-right:10px;'>
                            <b>Text:</b> {row['text']}<br>
                            <b>Score:</b> {row['score']}<br>
                            <b>Positive keywords:</b> {', '.join(row['pos']) if row['pos'] else 'None'}<br>
                            <b>Negative keywords:</b> {', '.join(row['neg']) if row['neg'] else 'None'}<br>
                            <b>Text-image similarity:</b> {row['clip_l14_similarity_score']}</br>
                        </div>
                        <div>
                            <img src="{row["url"]}" style="max-width:300px; border:2px solid #ddd; border-radius:5px;">
                        </div>
                    </div>
                    """
                display(HTML(info_html))


            self.counter_widget.value = f"<center><b>Mapy {self.current_position + 1} – {min(self.current_position + self.batch_size, len(self.df))} / {len(self.df)}</b></center>"


    def show_next(self, b=None):
        if self.current_position + self.batch_size < len(self.indices):
            self.current_position += self.batch_size
            self.show_images()

    def show_previous(self, b=None):
        if self.current_position - self.batch_size >= 0:
            self.current_position -= self.batch_size
            self.show_images()

    def display(self):
        self.show_images()
        display(self.container)

# %%
df_maps.to_csv("sample_10k_first_keywords_attemp.csv")

# %%
MapViewerBatch(df_maps_negative, sort_by_score='asc', batch_size=20, show_text=True).display()
# Out:
# VBox(children=(HBox(children=(Button(description='← Previous', style=ButtonStyle()), HTML(value='<center><b>Ma…

# %% [markdown]
# Po obejrzeniu wyników:
#
# 1. Słownik generlanie działa dobrze, wprowadizłam małe zmiany.
# 2. W negative praktycznie nie ma map stat, jesli s to daltego że słaby opsi (ale nie wiecej niz 5 sztuK)
# 3. W netural słabe opisy, zdarzaj sie mapy stst =- byc moze neutral trezeba bedzie dołożyć do klasyfikatora korzystajcego z emmbedfings
# 4. W positive sa mapy stat - ale w zbiiorze i tak niue ma ich zbyt wiele.
# <!--  --><!--  -->
#
# Podejście 2 ze zaktualizownaymi słownikami:

# %%
import pandas as pd
import json

with open("./keywords/positive_keywords.json", "r", encoding="utf-8") as f:
    positive_json = json.load(f)

with open("./keywords/negative_keywords.json", "r", encoding="utf-8") as f:
    negative_json = json.load(f)


print(f"Loaded {len(positive_json)} positive keywords.")
print(f"Loaded {len(negative_json)} negative keywords.")
# Out:
# Loaded 2725 positive keywords.
# Loaded 2415 negative keywords.

# %%
df_maps = pd.read_csv("sample_10k_first_keywords_attemp.csv")

df_maps.head()
# Out:
#    Unnamed: 0                               uid  \
# 0           0  337d71949d50f8f2d8805a8b3fa3d81b
# 1           1  eae4819aef3d65027b8d28a230afc0f9
# 2           2  4ea106e4a5867df0f987300f2038cd4c
# 3           3  73a0bd1cc6080dd8985e2b790fe9a113
# 4           4  030e8a94dd1934c8c20eb85cc04d009d
#
#                                                  url url_status  \
# 0  http://a0.fast-meteo.com/maps/static/t_Austral...        ERR
# 1  https://cdn1.vectorstock.com/i/thumbs/22/75/fr...         OK
# 2    http://7.hikb.at:80/img/iconmenu/attraction.png         OK
# 3  https://aa1cc5ce659c48a883597af217799a86.objec...        ERR
# 4  http://images.slideplayer.com/9/2524694/slides...         OK
#
#                                                 text original_width  \
# 0                                   Australia Nuvola            120
# 1  French Southern Territories Rubber Stamps vect...            112
# 2                              New York - Látnivalók             64
# 3                                 Karte mit 5 bettel            210
# 4  2004 Weekday Arterial Hourly Volumes: 6 p.m. t...            960
#
#    original_height  clip_l14_similarity_score  \
# 0             96.0                   0.259766
# 1            118.0                   0.362793
# 2             64.0                   0.127808
# 3            210.0                   0.227539
# 4            720.0                   0.451660
#
#                                               sha256  score pos  \
# 0  e834f3dd906b36869fd707537734b6f7dfce2f2dcfda0d...    0.0  []
# 1  2ca3b7f2d2f2996a3800c001797ed3c7ee666ca82dbb87...   -5.0  []
# 2  c3f92275db5f9b35f2efe57d85fc0f547347b1fd361646...    0.0  []
# 3  4a46099a1e18fefd2523a532f4f3c0563926a90496bd91...    0.0  []
# 4  98e4271537a8193cef6ba4a5f3f64ba60f49d11aa19972...    0.0  []
#
#                    neg
# 0                   []
# 1  ['stamps', 'image']
# 2                   []
# 3                   []
# 4                   []

# %%
import ahocorasick

A = ahocorasick.Automaton()

for phrase, value in positive_json.items():
    A.add_word(phrase.lower(), ("pos", phrase, value))

for phrase, value in negative_json.items():
    A.add_word(phrase.lower(), ("neg", phrase, value))

A.make_automaton()

# %%
def compute_score_full_words(text):
    if not isinstance(text, str):
        text = str(text)

    text_lower = text.lower()
    score = 0
    used_phrases = set()
    pos_keys = []
    neg_keys = []

    for end_index, (ptype, phrase, value) in A.iter(text_lower):
        start_index = end_index - len(phrase) + 1

        if (start_index == 0 or not text_lower[start_index-1].isalnum()) and \
           (end_index == len(text_lower)-1 or not text_lower[end_index+1].isalnum()):

            if phrase not in used_phrases:
                score += value
                used_phrases.add(phrase)
                if ptype == "pos":
                    pos_keys.append(phrase)
                else:
                    neg_keys.append(phrase)

    return score, pos_keys, neg_keys

# %%
df_maps[["score_1", "pos_1", "neg_1"]] = df_maps["text"].apply(
    lambda x: pd.Series(compute_score_full_words(x))
)

df_maps[["text", "score", "pos", "neg", "score_1", "pos_1", "neg_1"]]
# Out:
#                                                     text  score pos  \
# 0                                       Australia Nuvola    0.0  []
# 1      French Southern Territories Rubber Stamps vect...   -5.0  []
# 2                                  New York - Látnivalók    0.0  []
# 3                                     Karte mit 5 bettel    0.0  []
# 4      2004 Weekday Arterial Hourly Volumes: 6 p.m. t...    0.0  []
# ...                                                  ...    ...  ..
# 9997   Free Floorplan Designer floor plans and site p...  -11.0  []
# 9998               Wolrd Map Coron Backpacker Guesthouse    0.0  []
# 9999                    c7d77b50192 Autopesula hinnakiri    0.0  []
# 10000  kaart · Kentucky · Rood · patroon · amerika · ...   -8.0  []
# 10001                                   267 Breckenridge    0.0  []
#
#                                          neg  score_1 pos_1  \
# 0                                         []      0.0    []
# 1                        ['stamps', 'image']     -5.0    []
# 2                                         []      0.0    []
# 3                                         []      0.0    []
# 4                                         []      0.0    []
# ...                                      ...      ...   ...
# 9997   ['floorplan', 'floor plans', 'plans']    -11.0    []
# 9998                                      []      0.0    []
# 9999                                      []      0.0    []
# 10000               ['patroon', 'stockfoto']     -8.0    []
# 10001                                     []      0.0    []
#
#                                  neg_1
# 0                                   []
# 1                      [stamps, image]
# 2                                   []
# 3                                   []
# 4                                   []
# ...                                ...
# 9997   [floorplan, floor plans, plans]
# 9998                                []
# 9999                                []
# 10000             [patroon, stockfoto]
# 10001                               []
#
# [10002 rows x 7 columns]

# %%
only_valid_urls_df = df_maps[df_maps['url_status'] == 'OK'].reset_index(drop=True)

df_maps_positive_1 = only_valid_urls_df[only_valid_urls_df['score_1'] > 0].reset_index(drop=True)
df_maps_negative_1 = only_valid_urls_df[only_valid_urls_df['score_1'] < 0].reset_index(drop=True)
df_maps_neutral_1 = only_valid_urls_df[only_valid_urls_df['score_1'] == 0].reset_index(drop=True)

print(f"Total valid URLs: {len(only_valid_urls_df)}")
print(f"Positive score maps: {len(df_maps_positive_1)}")
print(f"Negative score maps: {len(df_maps_negative_1)}")
print(f"Neutral score maps: {len(df_maps_neutral_1)}")
# Out:
# Total valid URLs: 5475
# Positive score maps: 342
# Negative score maps: 1974
# Neutral score maps: 3159

# %% [markdown]
# ### Wyniki podejścia 1:
# - Positive score maps: 368
# - Negative score maps: 1901
# - Neutral score maps: 3206
#
# ### Wyniki podejścia 2:
# - Positive score maps: 344
# - Negative score maps: 1973
# - Neutral score maps: 3158

# %%
conflicting_maps_pos_to_neg = df_maps[
    ((df_maps['score'] > 0) & (df_maps['score_1'] < 0))
]

conflicting_maps_neg_to_pos = df_maps[
    ((df_maps['score'] < 0) & (df_maps['score_1'] > 0))
]

conflicting_maps_pos_to_neutral = df_maps[
    ((df_maps['score'] > 0) & (df_maps['score_1'] == 0))
]

conflicting_maps_neg_to_neutral = df_maps[
    ((df_maps['score'] < 0) & (df_maps['score_1'] == 0))
]

conflicting_maps_neutral_to_pos = df_maps[
    ((df_maps['score'] == 0) & (df_maps['score_1'] > 0))
]

conflicting_maps_neutral_to_neg = df_maps[
    ((df_maps['score'] == 0) & (df_maps['score_1'] < 0))
]

# %%
import ipywidgets as widgets
from IPython.display import display, HTML
import numpy as np

class MapViewerBatchAttemp2:
    def __init__(self, df, sort_by_score=None, batch_size=4, show_text=True):
        self.df = df.copy().reset_index(drop=True)
        self.batch_size = batch_size
        self.show_text = show_text

        if sort_by_score == 'asc':
            self.df.sort_values('score_1', ascending=True, inplace=True)
        elif sort_by_score == 'desc':
            self.df.sort_values('score_1', ascending=False, inplace=True)

        self.indices = np.arange(len(self.df))
        self.current_position = 0

        self.image_widget = widgets.Output()
        self.prev_button_top = widgets.Button(description='← Previous')
        self.next_button_top = widgets.Button(description='Next →')
        self.prev_button_bottom = widgets.Button(description='← Previous')
        self.next_button_bottom = widgets.Button(description='Next →')
        self.counter_widget = widgets.HTML()

        for btn in [self.prev_button_top, self.prev_button_bottom]:
            btn.on_click(self.show_previous)
        for btn in [self.next_button_top, self.next_button_bottom]:
            btn.on_click(self.show_next)

        self.nav_top = widgets.HBox([self.prev_button_top, self.counter_widget, self.next_button_top])
        self.nav_bottom = widgets.HBox([self.prev_button_bottom, self.next_button_bottom])

        self.container = widgets.VBox([self.nav_top, self.image_widget, self.nav_bottom])

    def get_current_indices(self):
        start = self.current_position
        end = min(self.current_position + self.batch_size, len(self.df))
        return self.indices[start:end]

    def show_images(self, b=None):
        self.image_widget.clear_output(wait=True)

        with self.image_widget:
            for idx in self.get_current_indices():
                row = self.df.iloc[idx]

                if not self.show_text:
                    info_html = f"""
                <div style='display:flex; align-items:flex-start; padding:5px; margin-bottom:15px; border:1px solid #eee; border-radius:5px;'>
                    <div style='flex:1; padding-right:10px;'>
                        <b>Score NEW:</b> {row['score_1']}<br>
                        <b>Score OLD:</b> {row['score']}<br>
                        <b>Positive keywords:</b> {', '.join(row['pos_1']) if row['pos_1'] else 'None'}<br>
                        <b>Negative keywords:</b> {', '.join(row['neg_1']) if row['neg_1'] else 'None'}<br>
                        <b>Text-image similarity:</b> {row['clip_l14_similarity_score']}</br>
                    </div>
                    <div>
                        <img src="{row["url"]}" style="max-width:300px; border:2px solid #ddd; border-radius:5px;">
                    </div>
                </div>
                """
                else:
                    info_html = f"""
                    <div style='display:flex; align-items:flex-start; padding:5px; margin-bottom:15px; border:1px solid #eee; border-radius:5px;'>
                        <div style='flex:1; padding-right:10px;'>
                            <b>Text:</b> {row['text']}<br>
                            <b>Score NEW:</b> {row['score_1']}<br>
                            <b>Score OLD:</b> {row['score']}<br>
                            <b>Positive keywords:</b> {', '.join(row['pos_1']) if row['pos_1'] else 'None'}<br>
                            <b>Negative keywords:</b> {', '.join(row['neg_1']) if row['neg_1'] else 'None'}<br>
                            <b>Text-image similarity:</b> {row['clip_l14_similarity_score']}</br>
                        </div>
                        <div>
                            <img src="{row["url"]}" style="max-width:300px; border:2px solid #ddd; border-radius:5px;">
                        </div>
                    </div>
                    """
                display(HTML(info_html))


            self.counter_widget.value = f"<center><b>Mapy {self.current_position + 1} – {min(self.current_position + self.batch_size, len(self.df))} / {len(self.df)}</b></center>"


    def show_next(self, b=None):
        if self.current_position + self.batch_size < len(self.indices):
            self.current_position += self.batch_size
            self.show_images()

    def show_previous(self, b=None):
        if self.current_position - self.batch_size >= 0:
            self.current_position -= self.batch_size
            self.show_images()

    def display(self):
        self.show_images()
        display(self.container)

# %%
print(f"Maps changing from positive to negative: {len(conflicting_maps_pos_to_neg)}")
print(f"Maps changing from negative to positive: {len(conflicting_maps_neg_to_pos)}")
print(f"Maps changing from positive to neutral: {len(conflicting_maps_pos_to_neutral)}")
print(f"Maps changing from negative to neutral: {len(conflicting_maps_neg_to_neutral)}")
print(f"Maps changing from neutral to positive: {len(conflicting_maps_neutral_to_pos)}")
print(f"Maps changing from neutral to negative: {len(conflicting_maps_neutral_to_neg)}")
# Out:
# Maps changing from positive to negative: 64
# Maps changing from negative to positive: 1
# Maps changing from positive to neutral: 18
# Maps changing from negative to neutral: 2
# Maps changing from neutral to positive: 48
# Maps changing from neutral to negative: 48

# %%
MapViewerBatchAttemp2(conflicting_maps_neg_to_neutral, sort_by_score='asc', batch_size=20, show_text=True).display()
# Out:
# VBox(children=(HBox(children=(Button(description='← Previous', style=ButtonStyle()), HTML(value='<center><b>Ma…

# %%
df_maps.to_csv("../data/sample_10k_first_keywords_attemp2.csv", index=False)
